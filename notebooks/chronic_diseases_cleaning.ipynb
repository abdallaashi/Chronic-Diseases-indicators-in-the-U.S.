# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# # Read CSV

# %%
df = pd.read_csv("Raw_U.S._Chronic_Disease_Indicators_20250730.csv")
print(df.head())
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc     DataSource  \
# 0       2020     2020           US  United States          BRFSS
# 1       2015     2019           AR       Arkansas  US Cancer DVT
# 2       2015     2019           CA     California  US Cancer DVT
# 3       2015     2019           CO       Colorado  US Cancer DVT
# 4       2015     2019           GA        Georgia  US Cancer DVT
#
#            Topic                                           Question  Response  \
# 0  Health Status            Recent activity limitation among adults       NaN
# 1         Cancer    Invasive cancer (all sites combined), incidence       NaN
# 2         Cancer  Cervical cancer mortality among all females, u...       NaN
# 3         Cancer    Invasive cancer (all sites combined), incidence       NaN
# 4         Cancer  Prostate cancer mortality among all males, und...       NaN
#
#   DataValueUnit      DataValueType  ...  TopicID  QuestionID ResponseID  \
# 0        Number  Age-adjusted Mean  ...      HEA       HEA04        NaN
# 1        Number             Number  ...      CAN       CAN07        NaN
# 2        Number             Number  ...      CAN       CAN03        NaN
# 3        Number             Number  ...      CAN       CAN07        NaN
# 4        Number             Number  ...      CAN       CAN05        NaN
#
#   DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# 0      AGEADJMEAN                        SEX               SEXF
# 1            NMBR                        SEX               SEXM
# 2            NMBR                    OVERALL                OVR
# 3            NMBR                       RACE                HIS
# 4            NMBR                       RACE                WHT
#
#   StratificationCategoryID2 StratificationID2  StratificationCategoryID3  \
# 0                       NaN               NaN                        NaN
# 1                       NaN               NaN                        NaN
# 2                       NaN               NaN                        NaN
# 3                       NaN               NaN                        NaN
# 4                       NaN               NaN                        NaN
#
#    StratificationID3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 34 columns]

# %%
df
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0            2020     2020           US   United States
# 1            2015     2019           AR        Arkansas
# 2            2015     2019           CA      California
# 3            2015     2019           CO        Colorado
# 4            2015     2019           GA         Georgia
# ...           ...      ...          ...             ...
# 169457       2020     2020           VI  Virgin Islands
# 169458       2020     2021           WV   West Virginia
# 169459       2020     2020           WY         Wyoming
# 169460       2020     2020           WI       Wisconsin
# 169461       2020     2020           US   United States
#
#                     DataSource  \
# 0                        BRFSS
# 1                US Cancer DVT
# 2                US Cancer DVT
# 3                US Cancer DVT
# 4                US Cancer DVT
# ...                        ...
# 169457                   BRFSS
# 169458                    NSCH
# 169459                    NVSS
# 169460                   BRFSS
# 169461  CMS Part A Claims Data
#
#                                                   Topic  \
# 0                                         Health Status
# 1                                                Cancer
# 2                                                Cancer
# 3                                                Cancer
# 4                                                Cancer
# ...                                                 ...
# 169457                                    Health Status
# 169458  Nutrition, Physical Activity, and Weight Status
# 169459                           Cardiovascular Disease
# 169460                                     Immunization
# 169461                           Cardiovascular Disease
#
#                                                  Question  Response  \
# 0                 Recent activity limitation among adults       NaN
# 1         Invasive cancer (all sites combined), incidence       NaN
# 2       Cervical cancer mortality among all females, u...       NaN
# 3         Invasive cancer (all sites combined), incidence       NaN
# 4       Prostate cancer mortality among all males, und...       NaN
# ...                                                   ...       ...
# 169457  Fair or poor self-rated health status among ad...       NaN
# 169458  Children and adolescents aged 6-13 years meeti...       NaN
# 169459  Cerebrovascular disease (stroke) mortality amo...       NaN
# 169460                 Influenza vaccination among adults       NaN
# 169461  Hospitalization for heart failure as principal...       NaN
#
#             DataValueUnit      DataValueType  ...  TopicID  QuestionID  \
# 0                  Number  Age-adjusted Mean  ...      HEA       HEA04
# 1                  Number             Number  ...      CAN       CAN07
# 2                  Number             Number  ...      CAN       CAN03
# 3                  Number             Number  ...      CAN       CAN07
# 4                  Number             Number  ...      CAN       CAN05
# ...                   ...                ...  ...      ...         ...
# 169457                  %   Crude Prevalence  ...      HEA       HEA01
# 169458                  %   Crude Prevalence  ...     NPAW       NPW07
# 169459  cases per 100,000  Age-adjusted Rate  ...      CVD       CVD07
# 169460                  %   Crude Prevalence  ...      IMM       IMM01
# 169461    cases per 1,000         Crude Rate  ...      NaN         NaN
#
#        ResponseID DataValueTypeID  StratificationCategoryID1  \
# 0             NaN      AGEADJMEAN                        SEX
# 1             NaN            NMBR                        SEX
# 2             NaN            NMBR                    OVERALL
# 3             NaN            NMBR                       RACE
# 4             NaN            NMBR                       RACE
# ...           ...             ...                        ...
# 169457        NaN         CRDPREV                        AGE
# 169458        NaN         CRDPREV                       RACE
# 169459        NaN      AGEADJRATE                        SEX
# 169460        NaN         CRDPREV                       RACE
# 169461        NaN             NaN                        NaN
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                    SEXF                       NaN               NaN
# 1                    SEXM                       NaN               NaN
# 2                     OVR                       NaN               NaN
# 3                     HIS                       NaN               NaN
# 4                     WHT                       NaN               NaN
# ...                   ...                       ...               ...
# 169457            AGE1844                       NaN               NaN
# 169458                WHT                       NaN               NaN
# 169459               SEXF                       NaN               NaN
# 169460                HIS                       NaN               NaN
# 169461                NaN                       NaN               NaN
#
#         StratificationCategoryID3  StratificationID3
# 0                             NaN                NaN
# 1                             NaN                NaN
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# ...                           ...                ...
# 169457                        NaN                NaN
# 169458                        NaN                NaN
# 169459                        NaN                NaN
# 169460                        NaN                NaN
# 169461                        NaN                NaN
#
# [169462 rows x 34 columns]

# %% [markdown]
# # Data Cleaning

# %%
nan_count = df.isna().sum()
print(nan_count)
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Question                          0
# Response                     169462
# DataValueUnit                     0
# DataValueType                     0
# DataValue                     53631
# DataValueAlt                  53632
# DataValueFootnoteSymbol      114422
# DataValueFootnote            114422
# LowConfidenceLimit            68116
# HighConfidenceLimit           68116
# StratificationCategory1           1
# Stratification1                   1
# StratificationCategory2      169462
# Stratification2              169462
# StratificationCategory3      169462
# Stratification3              169462
# Geolocation                    2453
# LocationID                        1
# TopicID                           1
# QuestionID                        1
# ResponseID                   169462
# DataValueTypeID                   1
# StratificationCategoryID1         1
# StratificationID1                 1
# StratificationCategoryID2    169462
# StratificationID2            169462
# StratificationCategoryID3    169462
# StratificationID3            169462
# dtype: int64

# %% [markdown]
# - Many Numerous NaN cells.
# - Mixed measurement units and types.
# - Disease data mixed across various questions.

# %%
#Cleaning Data - Dropping empty columns
df = df.drop(columns = ['Response', 'StratificationCategory2', 'Stratification2', 'StratificationCategory3', 'Stratification3', 'ResponseID', 'StratificationCategoryID2', 'StratificationID2', 'StratificationCategoryID3', 'StratificationID3'])
df
# Out:
#         YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0            2020     2020           US   United States
# 1            2015     2019           AR        Arkansas
# 2            2015     2019           CA      California
# 3            2015     2019           CO        Colorado
# 4            2015     2019           GA         Georgia
# ...           ...      ...          ...             ...
# 169457       2020     2020           VI  Virgin Islands
# 169458       2020     2021           WV   West Virginia
# 169459       2020     2020           WY         Wyoming
# 169460       2020     2020           WI       Wisconsin
# 169461       2020     2020           US   United States
#
#                     DataSource  \
# 0                        BRFSS
# 1                US Cancer DVT
# 2                US Cancer DVT
# 3                US Cancer DVT
# 4                US Cancer DVT
# ...                        ...
# 169457                   BRFSS
# 169458                    NSCH
# 169459                    NVSS
# 169460                   BRFSS
# 169461  CMS Part A Claims Data
#
#                                                   Topic  \
# 0                                         Health Status
# 1                                                Cancer
# 2                                                Cancer
# 3                                                Cancer
# 4                                                Cancer
# ...                                                 ...
# 169457                                    Health Status
# 169458  Nutrition, Physical Activity, and Weight Status
# 169459                           Cardiovascular Disease
# 169460                                     Immunization
# 169461                           Cardiovascular Disease
#
#                                                  Question      DataValueUnit  \
# 0                 Recent activity limitation among adults             Number
# 1         Invasive cancer (all sites combined), incidence             Number
# 2       Cervical cancer mortality among all females, u...             Number
# 3         Invasive cancer (all sites combined), incidence             Number
# 4       Prostate cancer mortality among all males, und...             Number
# ...                                                   ...                ...
# 169457  Fair or poor self-rated health status among ad...                  %
# 169458  Children and adolescents aged 6-13 years meeti...                  %
# 169459  Cerebrovascular disease (stroke) mortality amo...  cases per 100,000
# 169460                 Influenza vaccination among adults                  %
# 169461  Hospitalization for heart failure as principal...    cases per 1,000
#
#             DataValueType  DataValue  ...  HighConfidenceLimit  \
# 0       Age-adjusted Mean        2.9  ...                  2.9
# 1                  Number     9537.0  ...                  NaN
# 2                  Number      486.0  ...                  NaN
# 3                  Number     2880.0  ...                  NaN
# 4                  Number      519.0  ...                  NaN
# ...                   ...        ...  ...                  ...
# 169457   Crude Prevalence        NaN  ...                  NaN
# 169458   Crude Prevalence       34.0  ...                 39.4
# 169459  Age-adjusted Rate       30.2  ...                 35.8
# 169460   Crude Prevalence       32.4  ...                 41.9
# 169461         Crude Rate       21.9  ...                  NaN
#
#        StratificationCategory1      Stratification1  \
# 0                          Sex               Female
# 1                          Sex                 Male
# 2                      Overall              Overall
# 3               Race/Ethnicity             Hispanic
# 4               Race/Ethnicity  White, non-Hispanic
# ...                        ...                  ...
# 169457                     Age            Age 18-44
# 169458          Race/Ethnicity  White, non-Hispanic
# 169459                     Sex               Female
# 169460          Race/Ethnicity             Hispanic
# 169461                     NaN                  NaN
#
#                                            Geolocation  LocationID TopicID  \
# 0                                                  NaN        59.0     HEA
# 1         POINT (-92.27449074299966 34.74865012400045)         5.0     CAN
# 2        POINT (-120.99999953799971 37.63864012300047)         6.0     CAN
# 3       POINT (-106.13361092099967 38.843840757000464)         8.0     CAN
# 4         POINT (-83.62758034599966 32.83968109300048)        13.0     CAN
# ...                                                ...         ...     ...
# 169457                    POINT (-64.896335 18.335765)        78.0     HEA
# 169458    POINT (-80.71264013499967 38.66551020200046)        54.0    NPAW
# 169459   POINT (-108.10983035299967 43.23554134300048)        56.0     CVD
# 169460    POINT (-89.81637074199966 44.39319117400049)        55.0     IMM
# 169461                                             NaN         NaN     NaN
#
#        QuestionID DataValueTypeID  StratificationCategoryID1 StratificationID1
# 0           HEA04      AGEADJMEAN                        SEX              SEXF
# 1           CAN07            NMBR                        SEX              SEXM
# 2           CAN03            NMBR                    OVERALL               OVR
# 3           CAN07            NMBR                       RACE               HIS
# 4           CAN05            NMBR                       RACE               WHT
# ...           ...             ...                        ...               ...
# 169457      HEA01         CRDPREV                        AGE           AGE1844
# 169458      NPW07         CRDPREV                       RACE               WHT
# 169459      CVD07      AGEADJRATE                        SEX              SEXF
# 169460      IMM01         CRDPREV                       RACE               HIS
# 169461        NaN             NaN                        NaN               NaN
#
# [169462 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169462 entries, 0 to 169461
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  169462 non-null  int64
#  1   YearEnd                    169462 non-null  int64
#  2   LocationAbbr               169462 non-null  object
#  3   LocationDesc               169462 non-null  object
#  4   DataSource                 169462 non-null  object
#  5   Topic                      169462 non-null  object
#  6   Question                   169462 non-null  object
#  7   DataValueUnit              169462 non-null  object
#  8   DataValueType              169462 non-null  object
#  9   DataValue                  115831 non-null  float64
#  10  DataValueAlt               115830 non-null  float64
#  11  DataValueFootnoteSymbol    55040 non-null   object
#  12  DataValueFootnote          55040 non-null   object
#  13  LowConfidenceLimit         101346 non-null  float64
#  14  HighConfidenceLimit        101346 non-null  float64
#  15  StratificationCategory1    169461 non-null  object
#  16  Stratification1            169461 non-null  object
#  17  Geolocation                167009 non-null  object
#  18  LocationID                 169461 non-null  float64
#  19  TopicID                    169461 non-null  object
#  20  QuestionID                 169461 non-null  object
#  21  DataValueTypeID            169461 non-null  object
#  22  StratificationCategoryID1  169461 non-null  object
#  23  StratificationID1          169461 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 31.0+ MB

# %%
df['DataValueUnit'].unique()
# Out:
# array(['Number', 'per 100,000', '%', 'cases per 100,000', 'Years',
#        'cases per 1,000,000', 'cases per 1,000', 'gallons'], dtype=object)

# %%
#sorting based on number of cases and removing odd units

the_filter_1 = df['DataValueUnit'] == 'per 100,000' 
the_filter_2 = df['DataValueUnit'] == 'cases per 100,000' 
the_filter_3 = df['DataValueUnit'] == 'cases per 1,000,000'
the_filter_4 = df['DataValueUnit'] == 'cases per 1,000'
df1 = df[the_filter_1 | the_filter_2 | the_filter_3 | the_filter_4 ]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36648 entries, 10 to 169461
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  36648 non-null  int64
#  1   YearEnd                    36648 non-null  int64
#  2   LocationAbbr               36648 non-null  object
#  3   LocationDesc               36648 non-null  object
#  4   DataSource                 36648 non-null  object
#  5   Topic                      36648 non-null  object
#  6   Question                   36648 non-null  object
#  7   DataValueUnit              36648 non-null  object
#  8   DataValueType              36648 non-null  object
#  9   DataValue                  26089 non-null  float64
#  10  DataValueAlt               26088 non-null  float64
#  11  DataValueFootnoteSymbol    10559 non-null  object
#  12  DataValueFootnote          10559 non-null  object
#  13  LowConfidenceLimit         25984 non-null  float64
#  14  HighConfidenceLimit        25984 non-null  float64
#  15  StratificationCategory1    36647 non-null  object
#  16  Stratification1            36647 non-null  object
#  17  Geolocation                36089 non-null  object
#  18  LocationID                 36647 non-null  float64
#  19  TopicID                    36647 non-null  object
#  20  QuestionID                 36647 non-null  object
#  21  DataValueTypeID            36647 non-null  object
#  22  StratificationCategoryID1  36647 non-null  object
#  23  StratificationID1          36647 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 7.0+ MB

# %%
# Coverting all units to per 100,000 cases  
df1[df1['DataValueUnit']=='cases per 1,000,000']['DataValue'] = df1[df1['DataValueUnit']=='cases per 1,000,000']['DataValue']/10
df1[df1['DataValueUnit']=='cases per 1,000']['DataValue'] = df1[df1['DataValueUnit']=='cases per 1,000']['DataValue']*100
df1
# Out:
# C:\Users\a_o_a\AppData\Local\Temp\ipykernel_92284\3778872022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1['DataValueUnit']=='cases per 1,000,000']['DataValue'] = df1[df1['DataValueUnit']=='cases per 1,000,000']['DataValue']/10
# C:\Users\a_o_a\AppData\Local\Temp\ipykernel_92284\3778872022.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[df1['DataValueUnit']=='cases per 1,000']['DataValue'] = df1[df1['DataValueUnit']=='cases per 1,000']['DataValue']*100
#         YearStart  YearEnd LocationAbbr   LocationDesc  \
# 10           2015     2019           SD   South Dakota
# 11           2015     2019           TX          Texas
# 13           2015     2019           VT        Vermont
# 14           2015     2019           WV  West Virginia
# 15           2015     2019           WI      Wisconsin
# ...           ...      ...          ...            ...
# 169434       2020     2020           US  United States
# 169442       2020     2020           WV  West Virginia
# 169443       2020     2020           TX          Texas
# 169459       2020     2020           WY        Wyoming
# 169461       2020     2020           US  United States
#
#                     DataSource                                  Topic  \
# 10               US Cancer DVT                                 Cancer
# 11               US Cancer DVT                                 Cancer
# 13               US Cancer DVT                                 Cancer
# 14               US Cancer DVT                                 Cancer
# 15               US Cancer DVT                                 Cancer
# ...                        ...                                    ...
# 169434                    NVSS                 Cardiovascular Disease
# 169442                    NVSS  Chronic Obstructive Pulmonary Disease
# 169443                    NVSS  Chronic Obstructive Pulmonary Disease
# 169459                    NVSS                 Cardiovascular Disease
# 169461  CMS Part A Claims Data                 Cardiovascular Disease
#
#                                                  Question      DataValueUnit  \
# 10      Prostate cancer mortality among all males, und...        per 100,000
# 11      Cervical cancer mortality among all females, u...        per 100,000
# 13      Prostate cancer mortality among all males, und...        per 100,000
# 14      Breast cancer mortality among all females, und...        per 100,000
# 15        Invasive cancer (all sites combined), incidence        per 100,000
# ...                                                   ...                ...
# 169434  Diseases of the heart mortality among all peop...  cases per 100,000
# 169442  Chronic obstructive pulmonary disease mortalit...  cases per 100,000
# 169443  Chronic obstructive pulmonary disease mortalit...  cases per 100,000
# 169459  Cerebrovascular disease (stroke) mortality amo...  cases per 100,000
# 169461  Hospitalization for heart failure as principal...    cases per 1,000
#
#             DataValueType  DataValue  ...  HighConfidenceLimit  \
# 10             Crude Rate       20.2  ...                 22.2
# 11             Crude Rate        2.9  ...                  3.0
# 13             Crude Rate       23.0  ...                 25.5
# 14             Crude Rate       31.6  ...                 33.2
# 15      Age-adjusted Rate      444.6  ...                447.8
# ...                   ...        ...  ...                  ...
# 169434         Crude Rate       37.3  ...                 38.7
# 169442  Age-adjusted Rate        NaN  ...                  NaN
# 169443         Crude Rate       54.1  ...                 55.8
# 169459  Age-adjusted Rate       30.2  ...                 35.8
# 169461         Crude Rate       21.9  ...                  NaN
#
#        StratificationCategory1  \
# 10                     Overall
# 11                         Sex
# 13                     Overall
# 14                         Sex
# 15                         Sex
# ...                        ...
# 169434          Race/Ethnicity
# 169442          Race/Ethnicity
# 169443                     Age
# 169459                     Sex
# 169461                     NaN
#
#                                        Stratification1  \
# 10                                             Overall
# 11                                              Female
# 13                                             Overall
# 14                                              Female
# 15                                              Female
# ...                                                ...
# 169434                       Multiracial, non-Hispanic
# 169442  American Indian or Alaska Native, non-Hispanic
# 169443                                       Age 45-64
# 169459                                          Female
# 169461                                             NaN
#
#                                           Geolocation  LocationID TopicID  \
# 10      POINT (-100.3735306369997 44.353130053000484)        46.0     CAN
# 11      POINT (-99.42677020599967 31.827240407000488)        48.0     CAN
# 13       POINT (-72.51764079099962 43.62538123900049)        50.0     CAN
# 14       POINT (-80.71264013499967 38.66551020200046)        54.0     CAN
# 15       POINT (-89.81637074199966 44.39319117400049)        55.0     CAN
# ...                                               ...         ...     ...
# 169434                                            NaN        59.0     CVD
# 169442   POINT (-80.71264013499967 38.66551020200046)        54.0    COPD
# 169443  POINT (-99.42677020599967 31.827240407000488)        48.0    COPD
# 169459  POINT (-108.10983035299967 43.23554134300048)        56.0     CVD
# 169461                                            NaN         NaN     NaN
#
#        QuestionID DataValueTypeID  StratificationCategoryID1 StratificationID1
# 10          CAN05         CRDRATE                    OVERALL               OVR
# 11          CAN03         CRDRATE                        SEX              SEXF
# 13          CAN05         CRDRATE                    OVERALL               OVR
# 14          CAN02         CRDRATE                        SEX              SEXF
# 15          CAN07      AGEADJRATE                        SEX              SEXF
# ...           ...             ...                        ...               ...
# 169434      CVD09         CRDRATE                       RACE               MRC
# 169442     COPD06      AGEADJRATE                       RACE              AIAN
# 169443     COPD06         CRDRATE                        AGE           AGE4564
# 169459      CVD07      AGEADJRATE                        SEX              SEXF
# 169461        NaN             NaN                        NaN               NaN
#
# [36648 rows x 24 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36648 entries, 10 to 169461
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  36648 non-null  int64
#  1   YearEnd                    36648 non-null  int64
#  2   LocationAbbr               36648 non-null  object
#  3   LocationDesc               36648 non-null  object
#  4   DataSource                 36648 non-null  object
#  5   Topic                      36648 non-null  object
#  6   Question                   36648 non-null  object
#  7   DataValueUnit              36648 non-null  object
#  8   DataValueType              36648 non-null  object
#  9   DataValue                  26089 non-null  float64
#  10  DataValueAlt               26088 non-null  float64
#  11  DataValueFootnoteSymbol    10559 non-null  object
#  12  DataValueFootnote          10559 non-null  object
#  13  LowConfidenceLimit         25984 non-null  float64
#  14  HighConfidenceLimit        25984 non-null  float64
#  15  StratificationCategory1    36647 non-null  object
#  16  Stratification1            36647 non-null  object
#  17  Geolocation                36089 non-null  object
#  18  LocationID                 36647 non-null  float64
#  19  TopicID                    36647 non-null  object
#  20  QuestionID                 36647 non-null  object
#  21  DataValueTypeID            36647 non-null  object
#  22  StratificationCategoryID1  36647 non-null  object
#  23  StratificationID1          36647 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 7.0+ MB

# %%
df1.describe()
# Out:
#           YearStart       YearEnd      DataValue   DataValueAlt  \
# count  36648.000000  36648.000000   26089.000000   26088.000000
# mean    2018.206669   2019.481500     106.666495     106.669744
# std        1.918871      0.504988     843.281862     843.297861
# min     2015.000000   2019.000000       0.200000       0.200000
# 25%     2016.000000   2019.000000      14.100000      14.100000
# 50%     2019.000000   2019.000000      41.010000      41.055000
# 75%     2020.000000   2020.000000     125.600000     125.600000
# max     2021.000000   2021.000000  131357.000000  131357.000000
#
#        LowConfidenceLimit  HighConfidenceLimit    LocationID
# count        25984.000000         25984.000000  36647.000000
# mean            90.443406           102.736965     28.526401
# std            134.250931           142.761212     15.728626
# min              0.100000             0.300000      1.000000
# 25%             12.117500            16.000000     16.000000
# 50%             36.100000            45.420000     28.000000
# 75%            114.500000           134.470000     41.000000
# max           1365.800000          1423.100000     72.000000

# %%
#Coverting year start to date time
df1['YearStart'] = pd.to_datetime(df1['YearStart'], format='%Y').dt.year
df1['YearStart'].dtypes
# Out:
# C:\Users\a_o_a\AppData\Local\Temp\ipykernel_92284\188513908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['YearStart'] = pd.to_datetime(df1['YearStart'], format='%Y').dt.year
# dtype('int32')

# %%
#Coverting year start to date time
df1['YearEnd'] = pd.to_datetime(df1['YearEnd'], format='%Y').dt.year
df1['YearEnd'].dtypes
# Out:
# C:\Users\a_o_a\AppData\Local\Temp\ipykernel_92284\4291124445.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['YearEnd'] = pd.to_datetime(df1['YearEnd'], format='%Y').dt.year
# dtype('int32')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36648 entries, 10 to 169461
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  36648 non-null  int32
#  1   YearEnd                    36648 non-null  int32
#  2   LocationAbbr               36648 non-null  object
#  3   LocationDesc               36648 non-null  object
#  4   DataSource                 36648 non-null  object
#  5   Topic                      36648 non-null  object
#  6   Question                   36648 non-null  object
#  7   DataValueUnit              36648 non-null  object
#  8   DataValueType              36648 non-null  object
#  9   DataValue                  26089 non-null  float64
#  10  DataValueAlt               26088 non-null  float64
#  11  DataValueFootnoteSymbol    10559 non-null  object
#  12  DataValueFootnote          10559 non-null  object
#  13  LowConfidenceLimit         25984 non-null  float64
#  14  HighConfidenceLimit        25984 non-null  float64
#  15  StratificationCategory1    36647 non-null  object
#  16  Stratification1            36647 non-null  object
#  17  Geolocation                36089 non-null  object
#  18  LocationID                 36647 non-null  float64
#  19  TopicID                    36647 non-null  object
#  20  QuestionID                 36647 non-null  object
#  21  DataValueTypeID            36647 non-null  object
#  22  StratificationCategoryID1  36647 non-null  object
#  23  StratificationID1          36647 non-null  object
# dtypes: float64(5), int32(2), object(17)
# memory usage: 6.7+ MB

# %%
# Saving cleaned data and reseting the index
df1.to_csv('USCDI_Cleaned.csv', index=False)
df_q3 = df1.reset_index()
df_q3
# Out:
#         index  YearStart  YearEnd LocationAbbr   LocationDesc  \
# 0          10       2015     2019           SD   South Dakota
# 1          11       2015     2019           TX          Texas
# 2          13       2015     2019           VT        Vermont
# 3          14       2015     2019           WV  West Virginia
# 4          15       2015     2019           WI      Wisconsin
# ...       ...        ...      ...          ...            ...
# 36643  169434       2020     2020           US  United States
# 36644  169442       2020     2020           WV  West Virginia
# 36645  169443       2020     2020           TX          Texas
# 36646  169459       2020     2020           WY        Wyoming
# 36647  169461       2020     2020           US  United States
#
#                    DataSource                                  Topic  \
# 0               US Cancer DVT                                 Cancer
# 1               US Cancer DVT                                 Cancer
# 2               US Cancer DVT                                 Cancer
# 3               US Cancer DVT                                 Cancer
# 4               US Cancer DVT                                 Cancer
# ...                       ...                                    ...
# 36643                    NVSS                 Cardiovascular Disease
# 36644                    NVSS  Chronic Obstructive Pulmonary Disease
# 36645                    NVSS  Chronic Obstructive Pulmonary Disease
# 36646                    NVSS                 Cardiovascular Disease
# 36647  CMS Part A Claims Data                 Cardiovascular Disease
#
#                                                 Question      DataValueUnit  \
# 0      Prostate cancer mortality among all males, und...        per 100,000
# 1      Cervical cancer mortality among all females, u...        per 100,000
# 2      Prostate cancer mortality among all males, und...        per 100,000
# 3      Breast cancer mortality among all females, und...        per 100,000
# 4        Invasive cancer (all sites combined), incidence        per 100,000
# ...                                                  ...                ...
# 36643  Diseases of the heart mortality among all peop...  cases per 100,000
# 36644  Chronic obstructive pulmonary disease mortalit...  cases per 100,000
# 36645  Chronic obstructive pulmonary disease mortalit...  cases per 100,000
# 36646  Cerebrovascular disease (stroke) mortality amo...  cases per 100,000
# 36647  Hospitalization for heart failure as principal...    cases per 1,000
#
#            DataValueType  ...  HighConfidenceLimit  StratificationCategory1  \
# 0             Crude Rate  ...                 22.2                  Overall
# 1             Crude Rate  ...                  3.0                      Sex
# 2             Crude Rate  ...                 25.5                  Overall
# 3             Crude Rate  ...                 33.2                      Sex
# 4      Age-adjusted Rate  ...                447.8                      Sex
# ...                  ...  ...                  ...                      ...
# 36643         Crude Rate  ...                 38.7           Race/Ethnicity
# 36644  Age-adjusted Rate  ...                  NaN           Race/Ethnicity
# 36645         Crude Rate  ...                 55.8                      Age
# 36646  Age-adjusted Rate  ...                 35.8                      Sex
# 36647         Crude Rate  ...                  NaN                      NaN
#
#                                       Stratification1  \
# 0                                             Overall
# 1                                              Female
# 2                                             Overall
# 3                                              Female
# 4                                              Female
# ...                                               ...
# 36643                       Multiracial, non-Hispanic
# 36644  American Indian or Alaska Native, non-Hispanic
# 36645                                       Age 45-64
# 36646                                          Female
# 36647                                             NaN
#
#                                          Geolocation  LocationID  TopicID  \
# 0      POINT (-100.3735306369997 44.353130053000484)        46.0      CAN
# 1      POINT (-99.42677020599967 31.827240407000488)        48.0      CAN
# 2       POINT (-72.51764079099962 43.62538123900049)        50.0      CAN
# 3       POINT (-80.71264013499967 38.66551020200046)        54.0      CAN
# 4       POINT (-89.81637074199966 44.39319117400049)        55.0      CAN
# ...                                              ...         ...      ...
# 36643                                            NaN        59.0      CVD
# 36644   POINT (-80.71264013499967 38.66551020200046)        54.0     COPD
# 36645  POINT (-99.42677020599967 31.827240407000488)        48.0     COPD
# 36646  POINT (-108.10983035299967 43.23554134300048)        56.0      CVD
# 36647                                            NaN         NaN      NaN
#
#       QuestionID DataValueTypeID StratificationCategoryID1  StratificationID1
# 0          CAN05         CRDRATE                   OVERALL                OVR
# 1          CAN03         CRDRATE                       SEX               SEXF
# 2          CAN05         CRDRATE                   OVERALL                OVR
# 3          CAN02         CRDRATE                       SEX               SEXF
# 4          CAN07      AGEADJRATE                       SEX               SEXF
# ...          ...             ...                       ...                ...
# 36643      CVD09         CRDRATE                      RACE                MRC
# 36644     COPD06      AGEADJRATE                      RACE               AIAN
# 36645     COPD06         CRDRATE                       AGE            AGE4564
# 36646      CVD07      AGEADJRATE                       SEX               SEXF
# 36647        NaN             NaN                       NaN                NaN
#
# [36648 rows x 25 columns]

# %%
df_q3['LocationDesc'].unique()
# Out:
# array(['South Dakota', 'Texas', 'Vermont', 'West Virginia', 'Wisconsin',
#        'Florida', 'Illinois', 'Iowa', 'Kansas', 'Massachusetts',
#        'Minnesota', 'Mississippi', 'New Hampshire', 'South Carolina',
#        'Wyoming', 'Alaska', 'Delaware', 'Indiana', 'Maine', 'Maryland',
#        'Michigan', 'North Carolina', 'North Dakota', 'Oregon',
#        'United States', 'Alabama', 'Missouri', 'New Jersey', 'New York',
#        'Connecticut', 'Georgia', 'Hawaii', 'Montana', 'New Mexico',
#        'Oklahoma', 'Idaho', 'Arkansas', 'Louisiana', 'Kentucky',
#        'Arizona', 'California', 'Nebraska', 'Pennsylvania', 'Washington',
#        'Nevada', 'Ohio', 'District of Columbia', 'Rhode Island',
#        'Colorado', 'Virginia', 'Utah', 'Tennessee', 'Puerto Rico'],
#       dtype=object)
